# %%
import math 
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn

# %%
## -----------------------------------------------------------------
## load expression data
## -----------------------------------------------------------------
countsFile = "GSE152418_p20047_Study1_RawCounts.txt"
counts= pd.read_csv(
    countsFile,
    sep = "\t",
    header = 0,       ## first row has all the header information
    index_col = 0,    ## first column has gene names as row index info
)

# %%
## -----------------------------------------------------------------
## load sample annotations
## -----------------------------------------------------------------
annotFile = "GSE152418_series_matrix.txt"
annot = pd.read_csv(annotFile, sep="\t",skiprows=58, index_col=0, header = 0)

# %%
annot
# Out:
#                                                                     S145_nCOV001_C  \
# !Sample_title
# !Sample_geo_accession                                                   GSM4614985
# !Sample_status                                               Public on Jul 31 2020
# !Sample_submission_date                                                Jun 13 2020
# !Sample_last_update_date                                               Feb 01 2021
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                                       PBMC
# !Sample_organism_ch1                                                  Homo sapiens
# !Sample_characteristics_ch1                            days_post_symptom_onset: 40
# !Sample_characteristics_ch1                                              gender: M
# ...

# %%
counts.head()
# Out:
#                  S145_nCOV001_C  S147_nCoV001EUHM-Draw-1  \
# ENSEMBLID
# ENSG00000223972               0                        0
# ENSG00000227232               1                        0
# ENSG00000278267               3                        1
# ENSG00000243485               2                        0
# ENSG00000284332               0                        0
#
#                  S149_nCoV002EUHM-Draw-2  S150_nCoV003EUHM-Draw-1  \
# ENSEMBLID
# ENSG00000223972                        0                        0
# ENSG00000227232                        3                       16
# ENSG00000278267                        2                        0
# ENSG00000243485                        0                        1
# ENSG00000284332                        0                        0
#
#                  S151_nCoV004EUHM-Draw-1  S152_nCoV006EUHM-Draw-1  \
# ENSEMBLID
# ENSG00000223972                        0                        0
# ...
